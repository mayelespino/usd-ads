# %%
import numpy as np 
import matplotlib.pyplot as plt 

x = np.linspace(-np.pi, np.pi, 256)
c = np.cos(x)
s = np.sin(x)
plt.plot(x,s)
plt.plot(x,c)

# %%
x=[1,0]
y=[1,0]
print(x == y)
print(x is y)
# Out:
# True
# False
